# %%
#load libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
#load the jiji scrape dataset
df = pd.read_csv("data/jiji_car_scrap.csv")
df.head()
# Out:
#                                                title    make   model    year  \
# 0                       Land Rover Lr4 V8 2010 Black    Land   Rover     NaN
# 1                        New Toyota Hilux 2024 White     New  Toyota     NaN
# 2                           Toyota Sienna 2012 White  Toyota  Sienna  2012.0
# 3                                Lexus RX 2015 Black   Lexus      RX  2015.0
# 4  Mercedes-Benz C350 C350 BlueEFFICIENCY RWD 200...     NaN     NaN     NaN
#
#       condition transmission                   location          price
# 0    local used    automatic                      Isolo    ₦ 6,500,000
# 1           new    automatic                      Ikeja  ₦ 103,000,000
# 2    local used    automatic                     Ibadan   ₦ 12,700,000
# 3  foreign used    automatic  Central Business District   ₦ 30,000,000
# 4    local used    automatic      Kaduna / Kaduna State    ₦ 9,200,000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1979 entries, 0 to 1978
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1979 non-null   object
#  1   make          1626 non-null   object
#  2   model         1626 non-null   object
#  3   year          702 non-null    float64
#  4   condition     1979 non-null   object
#  5   transmission  1971 non-null   object
#  6   location      1979 non-null   object
#  7   price         1979 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 123.8+ KB

# %%
#check isnull df value
df.isnull().sum()
# Out:
# title              0
# make             353
# model            353
# year            1277
# condition          0
# transmission       8
# location           0
# price              0
# dtype: int64

# %%
#let's clean the price column
df['price'] = df['price'].astype(str).str.replace(r"[₦,]", "", regex=True).astype(float)
df.head(20)
# Out:
#                                                 title     make       model  \
# 0                        Land Rover Lr4 V8 2010 Black     Land       Rover
# 1                         New Toyota Hilux 2024 White      New      Toyota
# 2                            Toyota Sienna 2012 White   Toyota      Sienna
# 3                                 Lexus RX 2015 Black    Lexus          RX
# 4   Mercedes-Benz C350 C350 BlueEFFICIENCY RWD 200...      NaN         NaN
# 5                              Toyota Venza 2013 Gray   Toyota       Venza
# 6                            Lexus RX 350 2019 Orange    Lexus          RX
# 7                             Toyota Hilux 2020 White   Toyota       Hilux
# 8                               Honda Accord 2007 Red    Honda      Accord
# 9                          Toyota Corolla LE 2006 Red   Toyota     Corolla
# 10                            Peugeot 206 2004 Silver  Peugeot         206
# 11                 Mercedes-Benz GLC-Class 2017 Black      NaN         NaN
# 12                      Mercedes-Benz C300 2016 White      NaN         NaN
# 13  Toyota Camry SE 4dr Sedan (2.5L 4cyl 6A) 2013 Red   Toyota       Camry
# 14                            Toyota Matrix 2009 Gray   Toyota      Matrix
# 15                            Dodge Charger 2018 Gray    Dodge     Charger
# 16  Toyota Avalon Touring FWD Sedan (3.6L 6cyl 6A)...   Toyota      Avalon
# 17  Mercedes-Benz GLE-Class GLE 350d 4MATIC 2017 B...      NaN         NaN
# 18                       Mercedes-Benz E350 2015 Gray      NaN         NaN
# 19                        Toyota Highlander 2013 Gray   Toyota  Highlander
#
#       year     condition transmission                   location        price
# 0      NaN    local used    automatic                      Isolo    6500000.0
# 1      NaN           new    automatic                      Ikeja  103000000.0
# 2   2012.0    local used    automatic                     Ibadan   12700000.0
# 3   2015.0  foreign used    automatic  Central Business District   30000000.0
# 4      NaN    local used    automatic      Kaduna / Kaduna State    9200000.0
# 5   2013.0  foreign used    automatic                      Ojodu   24500000.0
# 6      NaN  foreign used    automatic                   Alimosho   55000000.0
# 7   2020.0    local used    automatic  Central Business District   47000000.0
# 8   2007.0    local used    automatic                   Gwarinpa    4000000.0
# 9      NaN  foreign used    automatic                     Ibadan    9500000.0
# 10  2004.0    local used       manual                        Jos    2820000.0
# 11     NaN  foreign used    automatic               Amuwo-Odofin   33500000.0
# 12     NaN  foreign used    automatic                       Ajah   26500000.0
# 13     NaN    local used    automatic                   Surulere   11850000.0
# 14  2009.0    local used    automatic              Ikotun/Igando    7300000.0
# 15  2018.0  foreign used    automatic                      Ojodu   48500000.0
# 16     NaN  foreign used    automatic                      Apapa   27000000.0
# 17     NaN  foreign used    automatic                      Apapa   44000000.0
# 18     NaN  foreign used    automatic                        Ojo   23000000.0
# 19  2013.0  foreign used    automatic               Amuwo-Odofin   19500000.0

# %%
#use pandas fillna to fill the nan column value
df['make'] = df['make'].fillna(df['title'].str.extract(r"(^\w+)")[0])
df['model'] = df['model'].fillna(df['title'].str.extract(r"^(?P<model>[A-Za-z0-9\-]+)")['model'])
df['year'] = df['year'].fillna(df['title'].str.extract(r"(\d{4})")[0]).astype(float)
# df['model'].head()
df['model'].head(20)
# Out:
# 0             Rover
# 1            Toyota
# 2            Sienna
# 3                RX
# 4     Mercedes-Benz
# 5             Venza
# 6                RX
# 7             Hilux
# 8            Accord
# 9           Corolla
# 10              206
# 11    Mercedes-Benz
# 12    Mercedes-Benz
# 13            Camry
# 14           Matrix
# 15          Charger
# 16           Avalon
# 17    Mercedes-Benz
# 18    Mercedes-Benz
# 19       Highlander
# Name: model, dtype: object

# %%
#drop subset row
df.dropna(subset=['year', 'transmission'], inplace=True)
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1969 entries, 0 to 1978
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1969 non-null   object
#  1   make          1969 non-null   object
#  2   model         1969 non-null   object
#  3   year          1969 non-null   float64
#  4   condition     1969 non-null   object
#  5   transmission  1969 non-null   object
#  6   location      1969 non-null   object
#  7   price         1969 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 138.4+ KB

# %%
df['location'] = df['location'].str.replace(r"[\s\-/()]+", "", regex=True)
df['location'].unique()
# Out:
# array(['Isolo', 'Ikeja', 'Ibadan', 'CentralBusinessDistrict',
#        'KadunaKadunaState', 'Ojodu', 'Alimosho', 'Gwarinpa', 'Jos',
#        'AmuwoOdofin', 'Ajah', 'Surulere', 'IkotunIgando', 'Apapa', 'Ojo',
#        'Yaba', 'Lekki', 'Katampe', 'Mabushi', 'Uyo', 'Awka', 'Ikorodu',
#        'Shomolu', 'Warri', 'OshimiliSouth', 'Gbagada', 'Jahi', 'Magodo',
#        'Lokogoma', 'Agege', 'Ogba', 'Asokoro', 'Kubwa', 'Ogudu', 'Owerri',
#        'Nyanya', 'LugbeDistrict', 'Kaura', 'AbuleEgba', 'Wuye', 'Garki2',
#        'Galadimawa', 'Osogbo', 'Enugu', 'PortHarcourt', 'Onitsha',
#        'BeninCity', 'Durumi', 'AdoOdoOta', 'KanoMunicipal', 'ApoDistrict',
#        'Gudu', 'Ikoyi', 'Ojota', 'Kado', 'Maryland', 'AbeokutaNorth',
#        'EgbeIdimu', 'Utako', 'IlorinEast', 'AbeokutaSouth', 'Kosofe',
#        'Ilupeju', 'AdoEkiti', 'AbujaFCT', 'Ipaja', 'IkaSouth', 'Ejigbo',
#        'Zaria', 'Wuse2', 'VictoriaIsland', 'Mushin', 'Akure',
#        'IlorinSouth', 'Gaduwa', 'Gwagwalada', 'Ikwerre', 'Garki1', 'Jabi',
#        'Sagamu', 'Akinyele', 'Orumba', 'Wuse', 'Badagry', 'IfakoIjaiye',
#        'Ife', 'Bwari', 'Nnewi', 'Oshodi', 'ObafemiOwode', 'Oluyole',
#        'Mbora', 'AgbaraIgbesan', 'AgboyiKetu', 'DeltaState', 'Maitama',
#        'ObioAkpor', 'Jikwoyi', 'Karu', 'LagosState'], dtype=object)

# %%
df.head()
# Out:
#                                                title      make          model  \
# 0                       Land Rover Lr4 V8 2010 Black      Land          Rover
# 1                        New Toyota Hilux 2024 White       New         Toyota
# 2                           Toyota Sienna 2012 White    Toyota         Sienna
# 3                                Lexus RX 2015 Black     Lexus             RX
# 4  Mercedes-Benz C350 C350 BlueEFFICIENCY RWD 200...  Mercedes  Mercedes-Benz
#
#      year     condition transmission                 location        price
# 0  2010.0    local used    automatic                    Isolo    6500000.0
# 1  2024.0           new    automatic                    Ikeja  103000000.0
# 2  2012.0    local used    automatic                   Ibadan   12700000.0
# 3  2015.0  foreign used    automatic  CentralBusinessDistrict   30000000.0
# 4  2008.0    local used    automatic        KadunaKadunaState    9200000.0
